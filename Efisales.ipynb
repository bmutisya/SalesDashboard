# %%
import requests
import pandas as pd
import json
from pandas import json_normalize


URL="https://portal.efisales.co.ke/rest/orders/product-orders?startDate=2022-01-13&endDate=2022-10-20"
#client_key = "ZtF1xoYpnvAHXlCxhNqZOydN5bGzSpiz"
#client_secret= "kHwXrtwab7e520t3zke7m4onY1eM4CD7ajDlGuYYDvRaxBlpq82v9nDW"
#response= requests.get(URL,auth=(client_key,client_secret))
#print(response.text)
headers ={'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJST0xFX0FETUlOIiwiYXV0aCI6IkFETUlOSVNUUkFUSU9OLFJFUFJFU0VOVEFUSVZFUyxST0xFX01BTkFHRVIsUk9MRV9BRE1JTiIsInJvbGUiOiJST0xFX0FETUlOIiwic2FsZXN1bml0SWQiOjM4NzAsImN1c3RvbWVySWQiOjczLCJleHAiOjE3MTc3NDYxMTR9.13OyVFT3cjb7mJXR_0TS2-OEXnqV04Dg600hkSLUAB_zGjs91x-STww0ojkeY5W4g5m9IuctvkTjFGmoAJjzsA'
          }
#print(headers)
response = requests.get(URL,headers=headers)
#if  response.status_code == 200:
response= response.json()
#marks =pd.DataFrame(response)
#df2=json_normalize(response['data'])

# how to get data from the first dictionary
br= response['data']
# convert the first dictionary into a dataframe
df=pd.DataFrame.from_records(br)
df
# Out:
#              category        city clientCategory clientCode clientIndustry
# 0            Bar Soap      Nakuru           Shop                    Retail  \
# 1                 Fat      Kamere          Kiosk                    Retail
# 2            Bar Soap      Kamere          Kiosk                    Retail
# 3            Bar Soap      Kamere          Kiosk                    Retail
# 4                 Oil      Emali-
# ...               ...         ...            ...        ...            ...
# 29362        Bar Soap      Salgaa
# 29363  Washing Powder  ekalakala           Kiosk                    Retail
# 29364  Washing Powder  ekalakala           Kiosk                    Retail
# 29365        Bar Soap      Nakuru           Shop                    Retail
# 29366        Bar Soap      nakuru           Shop                    Retail
#
#              clientName clientSize customerRef             dateSold   price
# ...

# %%
filt = df['salesRep'] == 'Francis Kanza'

# %%
df[filt]
# Out:
#      category            city   clientCategory clientCode clientIndustry
# 1    Bar Soap         Mombasa  Wholesaler Shop                 Wholesale  \
# 2      Cp Oil         Mombasa  Wholesaler Shop                 Wholesale
# 3      Cp Oil         Mombasa  Wholesaler Shop                 Wholesale
# 4      Cp Oil         Mombasa  Wholesaler Shop                 Wholesale
# 5      Cp Oil         Mombasa  Wholesaler Shop                 Wholesale
# 151  Bulk Oil         Mombasa  Wholesaler Shop                 Wholesale
# 194  Bulk Oil          Taveta  Wholesaler Shop                 Wholesale
# 195    Cp Oil          Taveta  Wholesaler Shop                 Wholesale
# 196    Cp Oil          Taveta  Wholesaler Shop                 Wholesale
# 374  Bar Soap       Mpeketoni  Wholesaler Shop                 Wholesale
# 486  Bar Soap       Mariakani  Wholesaler Shop                 Wholesale
# 595  Bar Soap          Taveta  Wholesaler Shop                 Wholesale
# ...

# %%
df3=df.groupby(by=["productName"]).sum()[["value"]].sort_values(by="value")
df3

# %%
df.dtypes
# Out:
# category               object
# city                   object
# clientCategory         object
# clientCode             object
# clientIndustry         object
# clientName             object
# clientSize             object
# customerRef            object
# dateSold               object
# price                  object
# productCode            object
# productId               int64
# productName            object
# productSubCategory     object
# quantity              float64
# quantityPerSku        float64
# routeName              object
# salesRep               object
# salesRepPhone          object
# salesUnit              object
# sku                    object
# supplier               object
# unitOfMeasurement      object
# value                 float64
# volumeInTonnes        float64
# dtype: object

# %%
date_col = pd.DatetimeIndex(df['dateSold'])
#date_col
#df['year']=date_col.year
df['month']=date_col.month
#df['Day']=date_col.day
import calendar
df['month'] = df['month'].apply(lambda x: calendar.month_abbr[x])
df.head()
# Out:
#    category       city   clientCategory clientCode clientIndustry
# 0  Bulk Oil  kirinyags        Groceries                    Retail  \
# 1  Bar Soap    Mombasa  Wholesaler Shop                 Wholesale
# 2    Cp Oil    Mombasa  Wholesaler Shop                 Wholesale
# 3    Cp Oil    Mombasa  Wholesaler Shop                 Wholesale
# 4    Cp Oil    Mombasa  Wholesaler Shop                 Wholesale
#
#          clientName clientSize customerRef             dateSold   price  ...
# 0    Nais Magunandu        SME              2022-10-20 09:44:57  3800.0  ...  \
# 1  Ezzi Traders Ltd                         2022-10-19 19:17:07  1225.0  ...
# 2  Ezzi Traders Ltd                         2022-10-19 19:17:07  5375.0  ...
# 3  Ezzi Traders Ltd                         2022-10-19 19:17:07  5200.0  ...
# 4  Ezzi Traders Ltd                         2022-10-19 19:17:07  3500.0  ...
#
#   salesRepPhone                 salesUnit sku       supplier
# ...

# %%
df.groupby(by=['salesRep']).sum()

# %%
df.dtypes

# %%
jupi=pd.DataFrame(df.groupby('salesRep')['clientName'].nunique())
jupi
# Out:
#                         clientName
# salesRep
# Andrew Mumo                    155
# Anne Wanjiru Kamau              25
# Assumter Mbele Muthini          22
# Benjamin Kiio Ndambuki         136
# Benjamin Nzioki                 35
# Catherine Kariuki               18
# Doreen Taa                     140
# Jackson Muiru                  163
# Jacob Mukula Muithi              5
# James Kingori                  201
# Janet Karani                    34
# Jarvis Nyamasyo                127
# John Mweu                      156
# John Ndeto                      84
# John Omeke Omweri               58
# Josiah Ing'ui                  219
# Kennedy Kyalo                  150
# Lucy Mwendwa                   157
# Mariam Mwanate                  45
# Mwatha Mwikya                   66
# Purity Muli                    113
# Reginah Mutuku                  77
# Risper Gichuru                 334
# Samwel Mbugua                  159

# %%
import matplotlib.pyplot as plt
import plotly.express as px
px.bar(jupi,x=jupi.index,y=jupi.clientName,orientation="v",
                        title="<b>Unique Clients Sold To</b>",
                        color_discrete_sequence=["#FF00FF"] *len (jupi),
                        template="plotly_white",)
# Out:
# <div>                            <div id="22d42722-cbd8-4a14-9824-765a22d7ee89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22d42722-cbd8-4a14-9824-765a22d7ee89")) {                    Plotly.newPlot(                        "22d42722-cbd8-4a14-9824-765a22d7ee89",                        [{"alignmentgroup":"True","hovertemplate":"salesRep=%{x}<br>clientName=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#FF00FF","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andrew Mumo","Anne Wanjiru Kamau","Assumter Mbele Muthini","Benjamin Kiio Ndambuki","Benjamin Nzioki","Catherine Kariuki","Doreen Taa","Jackson Muiru","Jacob Mukula Muithi","James Kingori","Janet Karani","Jarvis Nya
# ...

# %%
#add month
nan = df["routeName"] == 'NaN'
df[nan]

# %%
df['routeName'] = df['routeName'].replace(' ',0)
df.head(50)

# %%
nan_df = df[df.isna().any(axis=1)]
nan_df.head()

# %%
df= df.mask(df == '')
df
# Out:
#      category         city   clientCategory clientCode clientIndustry
# 0    Bulk Oil    kirinyags        Groceries        NaN         Retail  \
# 1    Bar Soap      Mombasa  Wholesaler Shop        NaN      Wholesale
# 2      Cp Oil      Mombasa  Wholesaler Shop        NaN      Wholesale
# 3      Cp Oil      Mombasa  Wholesaler Shop        NaN      Wholesale
# 4      Cp Oil      Mombasa  Wholesaler Shop        NaN      Wholesale
# ..        ...          ...              ...        ...            ...
# 914  Bar Soap  Kawangware   Wholesaler Shop        NaN      Wholesale
# 915    Cp Oil  Kawangware   Wholesaler Shop        NaN      Wholesale
# 916    Cp Oil  Kawangware   Wholesaler Shop        NaN      Wholesale
# 917    Cp Oil  Kawangware   Wholesaler Shop        NaN      Wholesale
# 918    Cp Oil  Kawangware   Wholesaler Shop        NaN      Wholesale
#
#               clientName clientSize customerRef             dateSold   price
# ...

# %%
import numpy as np
df['clientCategory']= df['clientCategory'].replace(np.nan, 'Uncategorised')
df.head(50)
# Out:
#                  category       city   clientCategory clientCode
# 0                Bulk Oil  kirinyags        Groceries        NaN  \
# 1                Bar Soap    Mombasa  Wholesaler Shop        NaN
# 2                  Cp Oil    Mombasa  Wholesaler Shop        NaN
# 3                  Cp Oil    Mombasa  Wholesaler Shop        NaN
# 4                  Cp Oil    Mombasa  Wholesaler Shop        NaN
# 5                  Cp Oil    Mombasa  Wholesaler Shop        NaN
# 6                Bar Soap      Matuu  Wholesaler Shop        NaN
# 7                Bar Soap      Matuu  Wholesaler Shop        NaN
# 8                Bar Soap      Matuu  Wholesaler Shop        NaN
# 9                Bar Soap      Matuu  Wholesaler Shop        NaN
# 10  Antbacterial Bar Soap      Matuu  Wholesaler Shop        NaN
# 11         White Bulk Fat      Matuu  Wholesaler Shop        NaN
# 12                 Cp Oil      Matuu  Wholesaler Shop        NaN
# ...

# %%
df['routeName'].unique()
# Out:
# array(['', ' Msa Island', 'MUMIAS ', 'Bondo', 'Kiritiiri - Siakago',
#        'Kisii ', 'Kithyoko', 'Nyeri', 'yala', 'Taveta', 'Githurai ',
#        ' PORT VICTORIA ', 'Mbale', 'karatina', 'Machakos', 'Malindi',
#        'SIO PORT ', 'Kimutwa/Yaitha/Muuma Andu', 'Mariakani', 'Garissa',
#        'Meru', 'mutituni', 'isiolo', 'MALABA ', 'nkubu', 'Chuka'],
#       dtype=object)

# %%
URL='https://portal.efisales.co.ke/rest/cost/mileagelogs?startDate=2017-01-01&endDate=2022-11-30'
#client_key = "ZtF1xoYpnvAHXlCxhNqZOydN5bGzSpiz"
#client_secret= "kHwXrtwab7e520t3zke7m4onY1eM4CD7ajDlGuYYDvRaxBlpq82v9nDW"
#response= requests.get(URL,auth=(client_key,client_secret))
#print(response.text)
headers ={'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJST0xFX0FETUlOIiwiYXV0aCI6IkFETUlOSVNUUkFUSU9OLFJFUFJFU0VOVEFUSVZFUyxST0xFX01BTkFHRVIsUk9MRV9BRE1JTiIsInJvbGUiOiJST0xFX0FETUlOIiwic2FsZXN1bml0SWQiOjQyMzQsImN1c3RvbWVySWQiOjg1LCJleHAiOjE3MTcyNTExMTB9.FRw6DadkMaeBAXiMUeO5Y7goD-XYnQ4xE0_FPiGCkRW5RqheSe6PBCvc1S10Tu_elJj7zNbakzepwro_mc66mg'
          }
#print(headers)
response = requests.get(URL,headers=headers)
#if  response.status_code == 200:
response= response.json()
#marks =pd.DataFrame(response)
#print(marks)
#df2=json_normalize(response['data'])

# how to get data from the first dictionary
cy= response['data']
# convert the first dictionary into a dataframe
mileage=pd.DataFrame.from_records(cy)
mileage

# %%
jup=pd.DataFrame(mileage.groupby('salesRep').sum()[["distance"]])

# %%
jup

# %%
Tum=jup.merge(jupi, how='left')
Tum
